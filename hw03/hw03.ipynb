# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, ConcatDataset, DataLoader
from PIL import Image
import os
import shutil

# Define transforms for data preprocessing (resize to 128x128)
transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# 数据增强，随机水平翻转，随机旋转15度，随机亮度、对比度
random_transform = transforms.Compose([
    transforms.Resize((128, 128)),
    transforms.RandomHorizontalFlip(),
    transforms.RandomRotation(15),
    transforms.ColorJitter(brightness=0.2, contrast=0.2, saturation=0.2, hue=0.1),
    # transforms.RandomErasing(p=0.5, scale=(0.02, 0.33)),
    # transforms.GaussianBlur(kernel_size=3, sigma=(0.1, 2.0)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.485, 0.456, 0.406], std=[0.229, 0.224, 0.225])
])

# Custom Dataset class for food images
class FoodDataset(Dataset):
    def __init__(self, root_dir, transform=None):
        self.root_dir = root_dir
        self.transform = transform
        self.classes = sorted([d for d in os.listdir(root_dir) if os.path.isdir(os.path.join(root_dir, d))])
        self.image_paths = []
        self.labels = []
        
        for class_idx, class_name in enumerate(self.classes):
            class_path = os.path.join(root_dir, class_name)
            if os.path.isdir(class_path):
                for img_name in os.listdir(class_path):
                    if img_name.endswith(('.jpg', '.jpeg', '.png')):
                        self.image_paths.append(os.path.join(class_path, img_name))
                        self.labels.append(class_idx)

    def __len__(self):
        return len(self.image_paths)

    def __getitem__(self, idx):
        img_path = self.image_paths[idx]
        image = Image.open(img_path).convert('RGB')
        label = self.labels[idx]
        
        if self.transform:
            image = self.transform(image)
            
        return image, label

# Create dataset and dataloader
train_dataset = FoodDataset(root_dir='food/training/labeled', transform=random_transform)
trylabeled_dataset = FoodDataset(root_dir='food/training/trylabeled', transform=transform)

# 使用ConcatDataset合并
combined_train_dataset = ConcatDataset([train_dataset, trylabeled_dataset])

train_loader = DataLoader(combined_train_dataset, batch_size=64, shuffle=True)

# Create validation dataset and dataloader
val_dataset = FoodDataset(root_dir='food/validation', transform=transform)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)


# Define the CNN model
class FoodClassifier(nn.Module):
    def __init__(self, num_classes=11):
        super(FoodClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.classifier = nn.Sequential(
            nn.Linear(256 * 16 * 16, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(512, 256),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(256, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# Initialize model, loss function, and optimizer
# For Apple Silicon (M1/M2/M3), use MPS device if available
device = torch.device("mps" if torch.backends.mps.is_available() else "cpu")
print(f"Using device: {device}")

model = FoodClassifier().to(device)
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.003)

def train(model, train_loader, criterion, optimizer, epoch, num_epochs):
    model.train()
    running_loss = 0.0
    for i, (images, labels) in enumerate(train_loader):
        images = images.to(device)
        labels = labels.to(device)
        
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
        if (i + 1) % 10 == 0:
            print(f'Epoch [{epoch+1}/{num_epochs}], Step [{i+1}/{len(train_loader)}], Loss: {running_loss/100:.4f}')
            running_loss = 0.0

def validate(model, val_loader, criterion):
    model.eval()
    accuracy = 0
    avg_loss = 0
    correct = 0
    running_loss = 0.0
    size = len(val_loader.dataset)
    num_batches = len(val_loader)
    
    with torch.no_grad():
        for images, labels in val_loader:
            images = images.to(device)
            labels = labels.to(device)
            
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_loss += loss.item()
            
            probabilities = F.softmax(outputs, dim=1)  # 计算每个类别的概率
            _, predicted = torch.max(probabilities, 1) 
            correct += (predicted == labels).sum().item()
    
    accuracy = 100 * correct / size
    avg_loss = running_loss / num_batches
    
    print(f'Validation Accuracy: {accuracy:.2f}%')
    print(f'Validation Loss: {avg_loss:.4f}')
    
    return accuracy, avg_loss
# Out:
# Using device: mps

# %%
# Training loop
num_epochs = 50
min_accuracy = 0

for epoch in range(num_epochs):
    train(model, train_loader, criterion, optimizer, epoch, num_epochs)
    accuracy, loss = validate(model, val_loader, criterion)
    if accuracy > min_accuracy:
        min_accuracy = accuracy
        torch.save(model.state_dict(), 'food_classifier.pth')

print("Finished!")
# Out:
# Epoch [1/50], Step [10/57], Loss: 0.2464
# Epoch [1/50], Step [20/57], Loss: 0.2381
# Epoch [1/50], Step [30/57], Loss: 0.2367
# Epoch [1/50], Step [40/57], Loss: 0.2310
# Epoch [1/50], Step [50/57], Loss: 0.2323
# Validation Accuracy: 13.79%
# Validation Loss: 2.2777
# Epoch [2/50], Step [10/57], Loss: 0.2311
# Epoch [2/50], Step [20/57], Loss: 0.2309
# Epoch [2/50], Step [30/57], Loss: 0.2253
# Epoch [2/50], Step [40/57], Loss: 0.2240
# Epoch [2/50], Step [50/57], Loss: 0.2242
# Validation Accuracy: 15.15%
# Validation Loss: 2.2547
# Epoch [49/50], Step [30/57], Loss: 0.0682
# Epoch [49/50], Step [40/57], Loss: 0.0648
# Epoch [49/50], Step [50/57], Loss: 0.0644
# Validation Accuracy: 34.39%
# Validation Loss: 2.2991
# Epoch [50/50], Step [10/57], Loss: 0.0519
# Epoch [50/50], Step [20/57], Loss: 0.0586
# Epoch [50/50], Step [30/57], Loss: 0.0665
# Epoch [50/50], Step [40/57], Loss: 0.0628
# Epoch [50/50], Step [50/57], Loss: 0.0707
# Validation Accuracy: 35.30%
# Validation Loss: 2.3533
# Finished!

# %%
# Load the saved model
model.load_state_dict(torch.load('food_classifier.pth'))
model.eval()


# Create output directory if it doesn't exist
output_base_dir = 'food/training/trylabeled'

# 如果目录存在，则删除
if os.path.exists(output_base_dir):
    shutil.rmtree(output_base_dir)

if not os.path.exists(output_base_dir):
    os.makedirs(output_base_dir)

# Create class subdirectories
for i in range(11):  # 11 food classes
    class_dir = os.path.join(output_base_dir, str(i))
    if not os.path.exists(class_dir):
        os.makedirs(class_dir)

# Process images
confidence_threshold = 0.99  # Adjust this threshold as needed
input_dir = 'food/training/unlabeled/00'

for filename in os.listdir(input_dir):
    if filename.endswith(('.jpg', '.jpeg', '.png')):
        # Load and preprocess image
        img_path = os.path.join(input_dir, filename)
        image = Image.open(img_path).convert('RGB')
        img_tensor = transform(image).unsqueeze(0).to(device)
        
        # Get prediction
        with torch.no_grad():
            outputs = model(img_tensor)
            probabilities = F.softmax(outputs, dim=1)
            max_prob, predicted_class = torch.max(probabilities, 1)
            
            # If confidence is high enough, copy to class directory
            if max_prob.item() > confidence_threshold:
                predicted_label = predicted_class.item()
                dest_path = os.path.join(output_base_dir, str(predicted_label), filename)
                shutil.copy2(img_path, dest_path)
                print(f'Copied {filename} to class {predicted_label} with confidence {max_prob.item():.4f}')

print("Classification complete!")
# Out:
# Copied 1353.jpg to class 4 with confidence 0.9997
# Copied 5647.jpg to class 10 with confidence 0.9902
# Copied 2128.jpg to class 9 with confidence 0.9994
# Copied 6428.jpg to class 9 with confidence 0.9993
# Copied 5121.jpg to class 10 with confidence 0.9996
# Copied 2302.jpg to class 9 with confidence 1.0000
# Copied 0501.jpg to class 9 with confidence 0.9999
# Copied 5323.jpg to class 9 with confidence 1.0000
# Copied 4798.jpg to class 9 with confidence 1.0000
# Copied 1019.jpg to class 9 with confidence 0.9997
# Copied 4820.jpg to class 9 with confidence 0.9996
# Copied 5280.jpg to class 9 with confidence 0.9959
# Copied 4405.jpg to class 9 with confidence 1.0000
# Copied 2074.jpg to class 5 with confidence 0.9917
# Copied 0663.jpg to class 6 with confidence 0.9906
# Copied 0688.jpg to class 9 with confidence 1.0000
# Copied 4410.jpg to class 9 with confidence 0.9991
# Copied 0676.jpg to class 9 with confidence 0.9997
# Copied 5256.jpg to class 4 with confidence 0.9961
# Copied 0448.jpg to class 1 with confidence 0.9925
# Copied 1018.jpg to class 9 with confidence 0.9984
# Copied 1187.jpg to class 9 with confidence 0.9962
# Copied 1193.jpg to class 9 with confidence 0.9972
# Copied 2459.jpg to class 9 with confidence 0.9998
# Copied 6617.jpg to class 9 with confidence 0.9902
# Copied 4772.jpg to class 9 with confidence 0.9986
# Copied 6398.jpg to class 9 with confidence 1.0000
# Copied 5875.jpg to class 9 with confidence 0.9997
# Copied 3551.jpg to class 9 with confidence 0.9997
# Copied 0058.jpg to class 5 with confidence 0.9936
# Copied 1434.jpg to class 10 with confidence 0.9998
# Copied 6373.jpg to class 6 with confidence 0.9992
# Copied 5108.jpg to class 9 with confidence 1.0000
# Copied 4570.jpg to class 6 with confidence 0.9978
# Copied 2117.jpg to class 9 with confidence 0.9953
# Copied 0714.jpg to class 9 with confidence 0.9960
# Copied 6403.jpg to class 5 with confidence 0.9932
# Copied 5308.jpg to class 1 with confidence 0.9906
# Copied 4758.jpg to class 9 with confidence 1.0000
# Copied 2329.jpg to class 9 with confidence 0.9949
# Copied 3751.jpg to class 9 with confidence 0.9999
# Copied 5334.jpg to class 9 with confidence 1.0000
# Copied 4176.jpg to class 2 with confidence 0.9907
# Copied 2275.jpg to class 9 with confidence 0.9957
# Copied 5532.jpg to class 6 with confidence 0.9929
# Copied 3625.jpg to class 9 with confidence 0.9998
# Copied 5526.jpg to class 9 with confidence 0.9996
# Copied 3816.jpg to class 5 with confidence 0.9977
# Copied 3180.jpg to class 10 with confidence 0.9998
# Copied 0489.jpg to class 9 with confidence 0.9998
# Copied 1783.jpg to class 9 with confidence 1.0000
# Copied 3341.jpg to class 9 with confidence 0.9997
# Copied 3433.jpg to class 9 with confidence 0.9999
# Copied 5917.jpg to class 5 with confidence 0.9961
# Copied 3383.jpg to class 10 with confidence 0.9979
# Copied 5916.jpg to class 9 with confidence 1.0000
# Copied 1219.jpg to class 6 with confidence 1.0000
# Copied 0675.jpg to class 10 with confidence 0.9999
# Copied 3817.jpg to class 2 with confidence 0.9961
# Copied 3156.jpg to class 9 with confidence 1.0000
# Copied 4605.jpg to class 10 with confidence 0.9966
# Copied 0463.jpg to class 8 with confidence 0.9940
# Copied 4942.jpg to class 9 with confidence 0.9999
# Copied 3977.jpg to class 10 with confidence 0.9974
# Copied 3744.jpg to class 9 with confidence 0.9998
# Copied 4995.jpg to class 9 with confidence 1.0000
# Copied 0271.jpg to class 5 with confidence 0.9948
# Copied 0517.jpg to class 1 with confidence 0.9991
# Copied 6166.jpg to class 9 with confidence 0.9989
# Copied 6172.jpg to class 9 with confidence 0.9972
# Copied 2472.jpg to class 4 with confidence 0.9950
# Copied 0098.jpg to class 9 with confidence 0.9936
# Copied 4598.jpg to class 9 with confidence 0.9950
# Copied 5876.jpg to class 9 with confidence 1.0000
# Copied 3220.jpg to class 4 with confidence 0.9974
# Copied 5651.jpg to class 9 with confidence 0.9999
# Copied 1423.jpg to class 1 with confidence 0.9988
# Copied 5645.jpg to class 9 with confidence 1.0000
# Copied 4239.jpg to class 5 with confidence 0.9976
# Copied 6374.jpg to class 9 with confidence 0.9933
# Copied 4211.jpg to class 9 with confidence 1.0000
# Copied 3581.jpg to class 9 with confidence 0.9976
# Copied 5457.jpg to class 10 with confidence 0.9933
# Copied 1631.jpg to class 10 with confidence 0.9999
# Copied 3740.jpg to class 9 with confidence 0.9999
# Copied 0329.jpg to class 8 with confidence 0.9932
# Copied 3152.jpg to class 10 with confidence 0.9943
# Copied 1023.jpg to class 9 with confidence 0.9997
# Copied 0467.jpg to class 9 with confidence 0.9997
# Copied 4601.jpg to class 10 with confidence 0.9970
# Copied 3807.jpg to class 9 with confidence 0.9903
# Copied 1962.jpg to class 9 with confidence 0.9978
# Copied 0895.jpg to class 9 with confidence 1.0000
# Copied 5047.jpg to class 9 with confidence 1.0000
# Copied 3350.jpg to class 4 with confidence 0.9993
# Copied 5085.jpg to class 9 with confidence 1.0000
# Copied 3386.jpg to class 9 with confidence 0.9998
# Copied 4364.jpg to class 4 with confidence 0.9911
# Copied 4416.jpg to class 1 with confidence 0.9998
# Copied 1208.jpg to class 9 with confidence 1.0000
# Copied 3190.jpg to class 9 with confidence 0.9995
# Copied 0300.jpg to class 1 with confidence 0.9937
# Copied 4166.jpg to class 9 with confidence 0.9955
# Copied 6605.jpg to class 9 with confidence 0.9989
# Copied 5330.jpg to class 9 with confidence 0.9999
# Copied 1624.jpg to class 9 with confidence 0.9998
# Copied 5867.jpg to class 9 with confidence 0.9915
# Copied 4548.jpg to class 9 with confidence 1.0000
# Copied 5118.jpg to class 9 with confidence 0.9974
# Copied 5695.jpg to class 10 with confidence 1.0000
# Copied 3596.jpg to class 6 with confidence 0.9991
# Copied 0921.jpg to class 9 with confidence 0.9990
# Copied 3031.jpg to class 10 with confidence 0.9955
# Copied 6607.jpg to class 10 with confidence 0.9923
# Copied 0510.jpg to class 10 with confidence 1.0000
# Copied 4004.jpg to class 9 with confidence 0.9993
# Copied 2529.jpg to class 9 with confidence 0.9960
# Copied 5252.jpg to class 2 with confidence 0.9970
# Copied 6773.jpg to class 2 with confidence 0.9930
# Copied 4825.jpg to class 10 with confidence 0.9939
# Copied 1975.jpg to class 9 with confidence 1.0000
# Copied 5050.jpg to class 9 with confidence 0.9955
# Copied 0896.jpg to class 9 with confidence 1.0000
# Copied 0666.jpg to class 2 with confidence 0.9986
# Copied 5092.jpg to class 10 with confidence 0.9990
# Copied 2702.jpg to class 9 with confidence 0.9997
# Copied 2064.jpg to class 9 with confidence 0.9916
# Copied 1579.jpg to class 9 with confidence 0.9989
# Copied 0883.jpg to class 9 with confidence 0.9989
# Copied 6766.jpg to class 9 with confidence 0.9995
# Copied 1009.jpg to class 9 with confidence 1.0000
# Copied 2272.jpg to class 5 with confidence 0.9993
# Copied 5247.jpg to class 9 with confidence 1.0000
# Copied 5482.jpg to class 9 with confidence 0.9994
# Copied 1182.jpg to class 4 with confidence 0.9928
# Copied 1828.jpg to class 4 with confidence 0.9963
# Copied 2474.jpg to class 9 with confidence 0.9979
# Copied 4777.jpg to class 10 with confidence 0.9973
# Copied 0908.jpg to class 9 with confidence 0.9999
# Copied 3568.jpg to class 9 with confidence 0.9999
# Copied 5125.jpg to class 9 with confidence 0.9962
# Copied 3232.jpg to class 9 with confidence 0.9988
# Copied 6477.jpg to class 10 with confidence 0.9901
# Copied 0748.jpg to class 9 with confidence 0.9906
# Copied 3533.jpg to class 5 with confidence 0.9977
# Copied 0947.jpg to class 9 with confidence 1.0000
# Copied 2407.jpg to class 9 with confidence 0.9981
# Copied 6107.jpg to class 9 with confidence 0.9995
# Copied 0562.jpg to class 9 with confidence 0.9936
# Copied 2413.jpg to class 10 with confidence 0.9939
# Copied 0204.jpg to class 10 with confidence 0.9940
# Copied 1640.jpg to class 9 with confidence 0.9911
# Copied 1126.jpg to class 9 with confidence 1.0000
# Copied 4089.jpg to class 9 with confidence 0.9991
# Copied 2215.jpg to class 9 with confidence 1.0000
# Copied 6067.jpg to class 9 with confidence 1.0000
# Copied 6701.jpg to class 9 with confidence 0.9998
# Copied 1734.jpg to class 9 with confidence 0.9959
# Copied 3876.jpg to class 1 with confidence 0.9940
# Copied 2771.jpg to class 9 with confidence 0.9985
# Copied 1536.jpg to class 9 with confidence 0.9988
# Copied 0833.jpg to class 6 with confidence 0.9954
# Copied 3446.jpg to class 10 with confidence 0.9937
# Copied 1537.jpg to class 1 with confidence 0.9988
# Copied 5745.jpg to class 10 with confidence 0.9995
# Copied 3334.jpg to class 9 with confidence 0.9994
# Copied 1084.jpg to class 8 with confidence 0.9958
# Copied 4842.jpg to class 10 with confidence 1.0000
# Copied 4881.jpg to class 9 with confidence 0.9967
# Copied 5209.jpg to class 10 with confidence 0.9990
# Copied 0588.jpg to class 9 with confidence 0.9981
# Copied 1866.jpg to class 10 with confidence 0.9999
# Copied 5341.jpg to class 8 with confidence 0.9900
# Copied 6648.jpg to class 1 with confidence 0.9997
# Copied 6660.jpg to class 10 with confidence 0.9996
# Copied 5194.jpg to class 9 with confidence 1.0000
# Copied 2638.jpg to class 9 with confidence 0.9996
# Copied 6310.jpg to class 9 with confidence 0.9997
# Copied 6304.jpg to class 9 with confidence 1.0000
# Copied 4505.jpg to class 9 with confidence 0.9999
# Copied 6460.jpg to class 8 with confidence 0.9915
# Copied 0207.jpg to class 5 with confidence 1.0000
# Copied 2362.jpg to class 5 with confidence 0.9937
# Copied 5425.jpg to class 9 with confidence 0.9925
# Copied 1657.jpg to class 9 with confidence 1.0000
# Copied 3929.jpg to class 9 with confidence 0.9998
# Copied 0415.jpg to class 9 with confidence 1.0000
# Copied 6070.jpg to class 9 with confidence 0.9937
# Copied 4883.jpg to class 10 with confidence 1.0000
# Copied 5223.jpg to class 9 with confidence 1.0000
# Copied 1045.jpg to class 8 with confidence 0.9978
# Copied 0398.jpg to class 5 with confidence 0.9967
# Copied 3450.jpg to class 9 with confidence 0.9980
# Copied 5747.jpg to class 9 with confidence 1.0000
# Copied 2969.jpg to class 9 with confidence 0.9967
# Copied 5790.jpg to class 9 with confidence 0.9985
# Copied 5948.jpg to class 9 with confidence 1.0000
# Copied 5949.jpg to class 10 with confidence 0.9953
# Copied 3451.jpg to class 9 with confidence 0.9923
# Copied 5752.jpg to class 9 with confidence 1.0000
# Copied 5034.jpg to class 1 with confidence 0.9968
# Copied 6515.jpg to class 9 with confidence 0.9952
# Copied 0164.jpg to class 9 with confidence 1.0000
# Copied 2001.jpg to class 9 with confidence 1.0000
# Copied 5587.jpg to class 10 with confidence 0.9999
# Copied 3848.jpg to class 9 with confidence 0.9959
# Copied 4869.jpg to class 10 with confidence 0.9929
# Copied 3135.jpg to class 9 with confidence 0.9991
# Copied 6059.jpg to class 9 with confidence 0.9952
# Copied 4100.jpg to class 9 with confidence 0.9997
# Copied 1859.jpg to class 9 with confidence 0.9993
# Copied 2377.jpg to class 9 with confidence 0.9993
# Copied 1332.jpg to class 9 with confidence 0.9994
# Copied 0986.jpg to class 9 with confidence 0.9999
# Copied 6461.jpg to class 9 with confidence 1.0000
# Copied 4510.jpg to class 5 with confidence 0.9910
# Copied 2613.jpg to class 10 with confidence 0.9993
# Copied 5178.jpg to class 9 with confidence 0.9999
# Copied 2617.jpg to class 9 with confidence 1.0000
# Copied 6303.jpg to class 10 with confidence 0.9950
# Copied 5811.jpg to class 9 with confidence 0.9965
# Copied 6115.jpg to class 9 with confidence 0.9958
# Copied 0570.jpg to class 1 with confidence 0.9978
# Copied 4892.jpg to class 9 with confidence 1.0000
# Copied 2561.jpg to class 5 with confidence 0.9901
# Copied 4662.jpg to class 9 with confidence 0.9961
# Copied 1524.jpg to class 9 with confidence 0.9971
# Copied 0174.jpg to class 9 with confidence 0.9994
# Copied 2005.jpg to class 9 with confidence 1.0000
# Copied 6277.jpg to class 1 with confidence 0.9915
# Copied 1294.jpg to class 9 with confidence 0.9992
# Copied 5794.jpg to class 9 with confidence 1.0000
# Copied 2992.jpg to class 9 with confidence 0.9994
# Copied 4688.jpg to class 9 with confidence 0.9923
# Copied 3859.jpg to class 9 with confidence 0.9985
# Copied 1733.jpg to class 9 with confidence 0.9920
# Copied 0571.jpg to class 9 with confidence 0.9994
# Copied 6672.jpg to class 9 with confidence 0.9999
# Copied 6128.jpg to class 9 with confidence 0.9930
# Copied 5810.jpg to class 9 with confidence 0.9990
# Copied 6464.jpg to class 1 with confidence 0.9908
# Copied 1451.jpg to class 1 with confidence 0.9964
# Copied 3246.jpg to class 9 with confidence 0.9999
# Copied 2158.jpg to class 10 with confidence 0.9984
# Copied 3244.jpg to class 9 with confidence 1.0000
# Copied 2600.jpg to class 9 with confidence 1.0000
# Copied 0771.jpg to class 9 with confidence 0.9991
# Copied 4517.jpg to class 9 with confidence 1.0000
# Copied 0229.jpg to class 9 with confidence 0.9999
# Copied 5379.jpg to class 9 with confidence 1.0000
# Copied 2370.jpg to class 10 with confidence 0.9902
# Copied 4113.jpg to class 2 with confidence 1.0000
# Copied 2562.jpg to class 9 with confidence 1.0000
# Copied 4675.jpg to class 5 with confidence 0.9970
# Copied 3683.jpg to class 9 with confidence 0.9909
# Copied 1255.jpg to class 9 with confidence 1.0000
# Copied 0822.jpg to class 9 with confidence 1.0000
# Copied 0188.jpg to class 4 with confidence 0.9967
# Copied 4310.jpg to class 6 with confidence 0.9936
# Copied 3325.jpg to class 9 with confidence 0.9984
# Copied 1917.jpg to class 9 with confidence 0.9940
# Copied 6063.jpg to class 9 with confidence 0.9999
# Copied 5218.jpg to class 9 with confidence 0.9995
# Copied 0360.jpg to class 6 with confidence 0.9937
# Copied 3641.jpg to class 9 with confidence 1.0000
# Copied 1056.jpg to class 6 with confidence 0.9947
# Copied 3906.jpg to class 8 with confidence 0.9973
# Copied 0599.jpg to class 4 with confidence 0.9954
# Copied 2371.jpg to class 9 with confidence 0.9972
# Copied 4700.jpg to class 9 with confidence 1.0000
# Copied 4714.jpg to class 9 with confidence 0.9997
# Copied 3053.jpg to class 9 with confidence 0.9980
# Copied 2359.jpg to class 10 with confidence 0.9957
# Copied 1136.jpg to class 10 with confidence 0.9984
# Copied 0228.jpg to class 7 with confidence 0.9960
# Copied 3721.jpg to class 10 with confidence 1.0000
# Copied 5813.jpg to class 5 with confidence 0.9992
# Copied 2832.jpg to class 10 with confidence 0.9980
# Copied 2198.jpg to class 5 with confidence 0.9928
# Copied 0764.jpg to class 9 with confidence 0.9991
# Copied 2173.jpg to class 9 with confidence 0.9908
# Copied 2615.jpg to class 9 with confidence 0.9973
# Copied 0016.jpg to class 9 with confidence 0.9997
# Copied 2167.jpg to class 9 with confidence 0.9938
# Copied 0758.jpg to class 9 with confidence 0.9925
# Copied 1334.jpg to class 9 with confidence 0.9987
# Copied 3245.jpg to class 10 with confidence 0.9999
# Copied 2142.jpg to class 9 with confidence 1.0000
# Copied 4241.jpg to class 9 with confidence 0.9920
# Copied 2630.jpg to class 1 with confidence 0.9908
# Copied 5611.jpg to class 10 with confidence 0.9995
# Copied 3260.jpg to class 8 with confidence 0.9995
# Copied 3512.jpg to class 10 with confidence 1.0000
# Copied 3274.jpg to class 9 with confidence 0.9981
# Copied 2195.jpg to class 9 with confidence 0.9963
# Copied 0972.jpg to class 10 with confidence 0.9987
# Copied 2817.jpg to class 9 with confidence 1.0000
# Copied 6132.jpg to class 9 with confidence 0.9999
# Copied 0225.jpg to class 10 with confidence 0.9920
# Copied 6654.jpg to class 9 with confidence 0.9962
# Copied 4094.jpg to class 9 with confidence 1.0000
# Copied 1846.jpg to class 9 with confidence 0.9990
# Copied 3937.jpg to class 9 with confidence 0.9971
# Copied 0379.jpg to class 4 with confidence 0.9990
# Copied 2208.jpg to class 9 with confidence 0.9960
# Copied 3116.jpg to class 9 with confidence 0.9996
# Copied 1098.jpg to class 10 with confidence 0.9988
# Copied 0392.jpg to class 9 with confidence 0.9952
# Copied 1259.jpg to class 9 with confidence 0.9961
# Copied 5995.jpg to class 9 with confidence 0.9995
# Copied 1271.jpg to class 10 with confidence 1.0000
# Copied 2976.jpg to class 10 with confidence 0.9998
# Copied 5957.jpg to class 10 with confidence 0.9904
# Copied 3467.jpg to class 9 with confidence 0.9963
# Copied 1270.jpg to class 4 with confidence 0.9978
# Copied 1502.jpg to class 10 with confidence 0.9997
# Copied 1714.jpg to class 10 with confidence 0.9992
# Copied 5200.jpg to class 9 with confidence 0.9992
# Copied 3895.jpg to class 9 with confidence 1.0000
# Copied 4903.jpg to class 5 with confidence 0.9973
# Copied 1847.jpg to class 10 with confidence 0.9976
# Copied 1853.jpg to class 5 with confidence 0.9950
# Copied 0595.jpg to class 10 with confidence 0.9999
# Copied 3077.jpg to class 9 with confidence 0.9915
# Copied 5374.jpg to class 1 with confidence 0.9966
# Copied 1674.jpg to class 9 with confidence 1.0000
# Copied 0768.jpg to class 9 with confidence 0.9989
# Copied 1310.jpg to class 7 with confidence 0.9977
# Copied 0026.jpg to class 10 with confidence 0.9990
# Copied 2157.jpg to class 9 with confidence 1.0000
# Copied 0998.jpg to class 1 with confidence 0.9989
# Copied 0032.jpg to class 6 with confidence 0.9971
# Copied 0030.jpg to class 8 with confidence 0.9963
# Copied 5148.jpg to class 8 with confidence 0.9987
# Copied 2141.jpg to class 9 with confidence 0.9992
# Copied 3277.jpg to class 5 with confidence 0.9999
# Copied 5835.jpg to class 8 with confidence 0.9947
# Copied 1138.jpg to class 9 with confidence 0.9965
# Copied 2425.jpg to class 9 with confidence 0.9979
# Copied 6643.jpg to class 9 with confidence 0.9989
# Copied 1662.jpg to class 9 with confidence 1.0000
# Copied 0568.jpg to class 9 with confidence 0.9992
# Copied 6680.jpg to class 9 with confidence 0.9979
# Copied 4915.jpg to class 6 with confidence 0.9999
# Copied 4652.jpg to class 9 with confidence 1.0000
# Copied 6086.jpg to class 9 with confidence 0.9917
# Copied 4875.jpg to class 1 with confidence 0.9945
# Copied 3459.jpg to class 10 with confidence 1.0000
# Copied 4336.jpg to class 9 with confidence 0.9902
# Copied 3317.jpg to class 9 with confidence 1.0000
# Copied 5015.jpg to class 9 with confidence 0.9984
# Copied 5997.jpg to class 9 with confidence 0.9996
# Copied 4860.jpg to class 4 with confidence 0.9941
# Copied 2593.jpg to class 9 with confidence 0.9999
# Copied 3896.jpg to class 9 with confidence 0.9993
# Copied 2222.jpg to class 9 with confidence 0.9999
# Copied 5388.jpg to class 9 with confidence 0.9998
# Copied 3921.jpg to class 10 with confidence 0.9987
# Copied 0794.jpg to class 10 with confidence 0.9992
# Copied 5175.jpg to class 9 with confidence 1.0000
# Copied 6326.jpg to class 10 with confidence 0.9936
# Copied 2632.jpg to class 9 with confidence 1.0000
# Copied 0009.jpg to class 9 with confidence 0.9909
# Copied 0753.jpg to class 10 with confidence 0.9941
# Copied 2805.jpg to class 10 with confidence 0.9991
# Copied 5830.jpg to class 10 with confidence 0.9974
# Copied 1667.jpg to class 9 with confidence 1.0000
# Copied 2352.jpg to class 10 with confidence 0.9999
# Copied 1129.jpg to class 5 with confidence 0.9941
# Copied 4737.jpg to class 9 with confidence 0.9988
# Copied 2568.jpg to class 9 with confidence 1.0000
# Copied 4131.jpg to class 9 with confidence 0.9992
# Copied 0343.jpg to class 8 with confidence 0.9985
# Copied 3845.jpg to class 9 with confidence 1.0000
# Copied 5005.jpg to class 9 with confidence 0.9999
# Copied 6524.jpg to class 9 with confidence 0.9996
# Copied 2756.jpg to class 9 with confidence 0.9961
# Copied 2965.jpg to class 9 with confidence 0.9981
# Copied 3449.jpg to class 6 with confidence 1.0000
# Copied 2743.jpg to class 9 with confidence 0.9996
# Copied 2019.jpg to class 9 with confidence 0.9991
# Copied 6096.jpg to class 9 with confidence 0.9974
# Copied 6082.jpg to class 9 with confidence 0.9989
# Copied 6733.jpg to class 5 with confidence 0.9997
# Copied 6041.jpg to class 4 with confidence 0.9963
# Copied 3139.jpg to class 9 with confidence 0.9981
# Copied 1706.jpg to class 9 with confidence 0.9919
# Copied 1841.jpg to class 9 with confidence 1.0000
# Copied 0236.jpg to class 10 with confidence 0.9990
# Copied 1896.jpg to class 10 with confidence 0.9992
# Copied 6653.jpg to class 10 with confidence 1.0000
# Copied 0791.jpg to class 9 with confidence 0.9984
# Copied 1464.jpg to class 5 with confidence 0.9913
# Copied 3265.jpg to class 10 with confidence 0.9954
# Copied 1466.jpg to class 9 with confidence 0.9992
# Copied 2635.jpg to class 1 with confidence 0.9999
# Copied 0787.jpg to class 1 with confidence 0.9938
# Copied 3067.jpg to class 9 with confidence 1.0000
# Copied 5416.jpg to class 9 with confidence 0.9932
# Copied 5364.jpg to class 5 with confidence 0.9982
# Copied 3729.jpg to class 9 with confidence 0.9998
# Copied 2386.jpg to class 1 with confidence 0.9913
# Copied 4085.jpg to class 9 with confidence 1.0000
# Copied 4683.jpg to class 10 with confidence 0.9951
# Copied 0624.jpg to class 9 with confidence 0.9979
# Copied 0156.jpg to class 9 with confidence 1.0000
# Copied 1248.jpg to class 10 with confidence 0.9977
# Copied 2796.jpg to class 9 with confidence 0.9948
# Copied 0396.jpg to class 3 with confidence 0.9974
# Copied 5588.jpg to class 9 with confidence 0.9996
# Copied 4872.jpg to class 9 with confidence 1.0000
# Copied 4655.jpg to class 9 with confidence 0.9989
# Copied 0369.jpg to class 1 with confidence 0.9963
# Copied 3106.jpg to class 5 with confidence 0.9973
# Copied 4047.jpg to class 9 with confidence 0.9914
# Copied 6136.jpg to class 9 with confidence 0.9982
# Copied 3072.jpg to class 5 with confidence 0.9944
# Copied 2152.jpg to class 10 with confidence 0.9999
# Copied 6320.jpg to class 10 with confidence 1.0000
# Copied 0779.jpg to class 10 with confidence 0.9993
# Copied 3264.jpg to class 10 with confidence 0.9943
# Copied 1366.jpg to class 9 with confidence 0.9908
# Copied 4593.jpg to class 8 with confidence 0.9971
# Copied 2492.jpg to class 9 with confidence 1.0000
# Copied 0454.jpg to class 6 with confidence 0.9911
# Copied 5262.jpg to class 10 with confidence 0.9964
# Copied 1004.jpg to class 9 with confidence 0.9998
# Copied 2294.jpg to class 9 with confidence 1.0000
# Copied 1979.jpg to class 10 with confidence 0.9986
# Copied 2733.jpg to class 9 with confidence 0.9998
# Copied 0130.jpg to class 10 with confidence 0.9976
# Copied 2069.jpg to class 9 with confidence 1.0000
# Copied 5712.jpg to class 9 with confidence 1.0000
# Copied 2928.jpg to class 4 with confidence 0.9973
# Copied 2900.jpg to class 9 with confidence 1.0000
# Copied 6597.jpg to class 9 with confidence 0.9946
# Copied 0119.jpg to class 10 with confidence 0.9909
# Copied 1549.jpg to class 10 with confidence 0.9980
# Copied 2040.jpg to class 9 with confidence 1.0000
# Copied 2054.jpg to class 5 with confidence 0.9998
# Copied 6781.jpg to class 10 with confidence 0.9901
# Copied 2518.jpg to class 10 with confidence 1.0000
# Copied 5263.jpg to class 10 with confidence 0.9986
# Copied 3612.jpg to class 9 with confidence 1.0000
# Copied 5539.jpg to class 4 with confidence 0.9912
# Copied 3941.jpg to class 6 with confidence 1.0000
# Copied 3799.jpg to class 9 with confidence 0.9907
# Copied 1617.jpg to class 9 with confidence 0.9991
# Copied 3766.jpg to class 9 with confidence 0.9995
# Copied 6144.jpg to class 9 with confidence 0.9980
# Copied 4035.jpg to class 4 with confidence 0.9991
# Copied 5868.jpg to class 9 with confidence 1.0000
# Copied 5698.jpg to class 9 with confidence 1.0000
# Copied 3216.jpg to class 9 with confidence 0.9963
# Copied 4221.jpg to class 4 with confidence 0.9954
# Copied 3572.jpg to class 4 with confidence 0.9903
# Copied 0251.jpg to class 10 with confidence 0.9991
# Copied 0286.jpg to class 9 with confidence 0.9989
# Copied 0325.jpg to class 1 with confidence 0.9999
# Copied 1013.jpg to class 5 with confidence 0.9989
# Copied 1761.jpg to class 10 with confidence 0.9929
# Copied 2268.jpg to class 9 with confidence 1.0000
# Copied 3176.jpg to class 2 with confidence 0.9982
# Copied 0655.jpg to class 10 with confidence 0.9949
# Copied 5705.jpg to class 9 with confidence 0.9987
# Copied 1588.jpg to class 9 with confidence 0.9997
# Copied 5936.jpg to class 1 with confidence 0.9998
# Copied 4397.jpg to class 1 with confidence 0.9984
# Copied 5062.jpg to class 10 with confidence 0.9922
# Copied 0668.jpg to class 9 with confidence 1.0000
# Copied 4340.jpg to class 1 with confidence 0.9992
# Copied 2043.jpg to class 9 with confidence 1.0000
# Copied 4432.jpg to class 10 with confidence 0.9915
# Copied 0324.jpg to class 4 with confidence 0.9978
# Copied 2255.jpg to class 8 with confidence 0.9956
# Copied 1990.jpg to class 9 with confidence 0.9995
# Copied 6741.jpg to class 9 with confidence 1.0000
# Copied 6190.jpg to class 9 with confidence 1.0000
# Copied 1614.jpg to class 9 with confidence 0.9999
# Copied 5466.jpg to class 9 with confidence 0.9998
# Copied 2309.jpg to class 9 with confidence 0.9967
# Copied 6635.jpg to class 9 with confidence 0.9994
# Copied 4546.jpg to class 9 with confidence 0.9921
# Copied 3229.jpg to class 9 with confidence 1.0000
# Copied 3563.jpg to class 10 with confidence 0.9992
# Copied 5884.jpg to class 9 with confidence 0.9999
# Copied 6433.jpg to class 6 with confidence 0.9934
# Copied 0042.jpg to class 9 with confidence 0.9989
# Copied 5648.jpg to class 9 with confidence 0.9987
# Copied 2866.jpg to class 9 with confidence 1.0000
# Copied 3013.jpg to class 5 with confidence 0.9979
# Copied 0240.jpg to class 10 with confidence 1.0000
# Copied 3952.jpg to class 9 with confidence 0.9973
# Copied 1837.jpg to class 9 with confidence 0.9960
# Copied 3601.jpg to class 9 with confidence 0.9919
# Copied 2279.jpg to class 9 with confidence 0.9995
# Copied 5516.jpg to class 9 with confidence 0.9991
# Copied 4608.jpg to class 9 with confidence 0.9940
# Copied 1764.jpg to class 9 with confidence 0.9934
# Copied 1957.jpg to class 9 with confidence 0.9994
# Copied 3832.jpg to class 10 with confidence 0.9997
# Copied 5072.jpg to class 9 with confidence 0.9960
# Copied 1200.jpg to class 9 with confidence 0.9999
# Copied 5066.jpg to class 1 with confidence 0.9996
# Copied 6235.jpg to class 9 with confidence 0.9913
# Copied 4387.jpg to class 6 with confidence 1.0000
# Copied 6591.jpg to class 9 with confidence 1.0000
# Copied 6552.jpg to class 9 with confidence 0.9990
# Copied 3416.jpg to class 6 with confidence 0.9912
# Copied 4621.jpg to class 9 with confidence 0.9982
# Copied 6022.jpg to class 9 with confidence 1.0000
# Copied 2278.jpg to class 5 with confidence 0.9908
# Copied 6142.jpg to class 10 with confidence 0.9993
# Copied 4999.jpg to class 4 with confidence 0.9913
# Copied 5311.jpg to class 9 with confidence 0.9921
# Copied 2697.jpg to class 9 with confidence 0.9987
# Copied 1375.jpg to class 9 with confidence 1.0000
# Copied 5107.jpg to class 9 with confidence 0.9977
# Copied 4219.jpg to class 9 with confidence 0.9940
# Copied 3574.jpg to class 4 with confidence 0.9965
# Copied 5139.jpg to class 9 with confidence 1.0000
# Copied 2865.jpg to class 9 with confidence 0.9998
# Copied 5850.jpg to class 9 with confidence 0.9997
# Copied 2468.jpg to class 9 with confidence 0.9961
# Copied 3038.jpg to class 9 with confidence 0.9969
# Copied 2326.jpg to class 8 with confidence 0.9975
# Copied 0294.jpg to class 9 with confidence 0.9998
# Copied 6197.jpg to class 10 with confidence 0.9986
# Copied 1015.jpg to class 10 with confidence 0.9990
# Copied 5529.jpg to class 9 with confidence 0.9995
# Copied 1968.jpg to class 9 with confidence 0.9997
# Copied 0486.jpg to class 9 with confidence 0.9994
# Copied 6236.jpg to class 1 with confidence 0.9999
# Copied 6222.jpg to class 10 with confidence 1.0000
# Copied 2093.jpg to class 9 with confidence 1.0000
# Copied 2087.jpg to class 10 with confidence 0.9922
# Copied 5925.jpg to class 2 with confidence 0.9920
# Copied 0875.jpg to class 9 with confidence 1.0000
# Copied 4346.jpg to class 5 with confidence 0.9979
# Copied 5702.jpg to class 9 with confidence 1.0000
# Copied 3824.jpg to class 9 with confidence 0.9968
# Copied 3830.jpg to class 10 with confidence 0.9997
# Copied 6747.jpg to class 9 with confidence 0.9998
# Copied 4144.jpg to class 8 with confidence 0.9976
# Copied 1982.jpg to class 9 with confidence 1.0000
# Copied 6196.jpg to class 8 with confidence 0.9941
# Copied 3978.jpg to class 9 with confidence 1.0000
# Copied 5851.jpg to class 9 with confidence 1.0000
# Copied 0915.jpg to class 9 with confidence 0.9945
# Copied 4568.jpg to class 9 with confidence 0.9966
# Copied 2119.jpg to class 9 with confidence 0.9997
# Classification complete!
